# %% [markdown]
# ## Day 14
# ## Date : 8 June 2019

# %%
import pandas as pd
df=pd.read_csv('DataFile/wc-at.csv')
df.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
df.shape
# Out:
# (109, 2)

# %%
df.tail(5)
# Out:
#      Waist     AT
# 104  100.1  124.0
# 105   93.3   62.2
# 106  101.8  133.0
# 107  107.9  208.0
# 108  108.5  208.0

# %%
df.columns
# Out:
# Index(['Waist', 'AT'], dtype='object')

# %%
df.corr()
# Out:
#           Waist        AT
# Waist  1.000000  0.818558
# AT     0.818558  1.000000

# %%
import seaborn as sb
sb.pairplot(df.iloc[:,:])

# %%
import statsmodels.formula.api as smf
ml=smf.ols('AT~Waist',data=df).fit()
type(ml)
# Out:
# statsmodels.regression.linear_model.RegressionResultsWrapper

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,1]

# %%
ml.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     AT   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     217.3
# Date:                Mon, 10 Jun 2019   Prob (F-statistic):           1.62e-27
# Time:                        11:27:08   Log-Likelihood:                -534.99
# No. Observations:                 109   AIC:                             1074.
# Df Residuals:                     107   BIC:                             1079.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -215.9815     21.796     -9.909      0.000    -259.190    -172.773
# ...

# %%
df.iloc[:,:-1]

# %%
import numpy as np

# %%
smf.ols('AT~np.log(Waist)',data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     AT   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.672
# Method:                 Least Squares   F-statistic:                     222.6
# Date:                Mon, 10 Jun 2019   Prob (F-statistic):           6.80e-28
# Time:                        11:22:42   Log-Likelihood:                -534.11
# No. Observations:                 109   AIC:                             1072.
# Df Residuals:                     107   BIC:                             1078.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
smf.ols("np.log(AT)~Waist",data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             np.log(AT)   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     258.3
# Date:                Mon, 10 Jun 2019   Prob (F-statistic):           2.68e-30
# Time:                        11:23:27   Log-Likelihood:                -40.123
# No. Observations:                 109   AIC:                             84.25
# Df Residuals:                     107   BIC:                             89.63
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7410      0.233      3.185      0.002       0.280       1.202
# ...

# %%
smf.ols('np.sqrt(AT)~np.sqrt(Waist)',data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            np.sqrt(AT)   R-squared:                       0.719
# Model:                            OLS   Adj. R-squared:                  0.716
# Method:                 Least Squares   F-statistic:                     273.2
# Date:                Mon, 10 Jun 2019   Prob (F-statistic):           3.16e-31
# Time:                        11:24:44   Log-Likelihood:                -201.20
# No. Observations:                 109   AIC:                             406.4
# Df Residuals:                     107   BIC:                             411.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((87, 1), (22, 1), (87,), (22,))

# %%
from sklearn.linear_model import LinearRegression as lr
# lr.fit(X_train, y_train)

# %%
# lr.predict(X_test)

# %%
y_test
# Out:
# 84     183.00
# 10      28.32
# 75     140.00
# 2       42.60
# 24      45.84
# 100    151.00
# 108    208.00
# 7       32.98
# 16      43.78
# 86     121.00
# 68      97.13
# 22      35.43
# 45     118.00
# 60      57.05
# 76     109.00
# 52     133.00
# 13      42.48
# 73     123.00
# 85     184.00
# 54      41.71
# 104    124.00
# 8       11.44
# Name: AT, dtype: float64

# %%
np.mean(y_test)
# Out:
# 94.21636363636365

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train,y_train,color='red')
# plt.plot(X_train,lr.predict(X_train))

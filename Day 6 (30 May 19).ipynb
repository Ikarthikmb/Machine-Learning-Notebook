# %% [markdown]
# ## Day 6
# ### Date : 30 May 2019

# %% [markdown]
# ### Q1. Draw a pie plot based on number of wins for each team

# %%
import pandas as pd
import matplotlib.pyplot as plt 
class read:
    pass
    def __init__(self,fname):
        self.df=pd.read_csv(fname)
    def win():
        winc=df['match_winner'].value_counts().values
        size=winc.tolist()
        teams=winc.to_frame.index.tolist()
    def Plot(size,teams):
        plt.pie(size,labels=teams,autopct='%1.1f',pctdistance=.9,startangle=90,radius=2.5,rotatelabels=1)
    
read('Match.csv').df
read.Plot(size,teams)

# %% [markdown]
# ### Q2  	Draw a bar graph for number of matches won (i,e.consider win if the team wins both the toss and match)  for the team “Mumbai Indians” for all years

# %%
import pandas as pd
import matplotlib.pyplot as plt
class tossMatch:
    def __init__(self):
        df=pd.read_csv('Match.csv')
    def ovw():
        val=df['Season_Year'][(df['match_winner']=='Mumbai Indians') & (df['Toss_Winner']=='Mumbai Indians')].value_counts()
        years=val.index.tolist()
        wins=val.tolist()
    def plot(years,wins):
        plt.bar(years,wins,align='edge',ecolor='black',xerr=1.5,yerr=None,alpha=1.5,visible=True)
tossMatch()
tossMatch.plot(years,wins)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-446-59c264b7ee43> in <module>
#      11         plt.bar(years,wins,align='edge',ecolor='black',xerr=1.5,yerr=None,alpha=1.5,visible=True)
#      12 tossMatch()
# ---> 13 tossMatch.plot(years,wins)
#
# <ipython-input-446-59c264b7ee43> in plot(years, wins)
#       9         wins=val.tolist()
#      10     def plot(years,wins):
# ...
